# %%
import pandas as pd
import numpy as np
# make a random dataframe
df = pd.DataFrame(np.random.randn(10, 5), columns=list('ABCDE'))
print(df)
# Out:
#           A         B         C         D         E
# 0 -2.218582  1.519815 -0.551696 -1.059015  1.122159
# 1  1.954818  0.503980 -0.245660  1.035725  1.057494
# 2  1.742052  1.388845 -0.806323  1.065724  1.048388
# 3 -0.615472 -1.213522 -1.517768  0.564901 -0.091460
# 4  0.030695  1.727080 -0.581376  1.176926  0.331133
# 5  2.079793 -1.164451  0.766000  1.390498 -0.236676
# 6 -2.172224 -0.541230 -0.537717 -1.237035  1.311458
# 7  0.321692 -0.313593  1.706910 -0.790717  1.282447
# 8 -1.459564 -0.658098  0.137895  1.558685 -1.512767
# 9  0.622998 -1.798488  1.028960  0.056128  1.442025

# %%
import networkx as nx
import matplotlib.pyplot as plt

G = nx.Graph()
G.add_node(1)
G.add_node(2)
G.add_node(3)
G.add_edge(2, 3)
G.add_edge(1, 3)
G.add_edge(1, 2)
subax1 = plt.subplot(121)
nx.draw(G, with_labels=True, font_weight='bold')
