# %%
import pandas as pd
import numpy as np
# make a random dataframe
df = pd.DataFrame(np.random.randn(10, 5), columns=list('ABCDE'))
print(df)
# Out:
#           A         B         C         D         E
# 0 -1.358848 -0.140832  0.498103 -0.246488  2.318507
# 1 -0.716008  0.751277  0.837597 -0.543655  0.572582
# 2  0.596577  0.147186 -0.114728  0.505231  1.455791
# 3 -1.094122  1.137860 -1.115391 -0.896698  0.379253
# 4  0.341075  1.336814  0.035954  2.682588  1.168047
# 5 -0.326118 -2.160372  2.092514  1.060366 -0.644410
# 6  0.307194 -0.757137  1.073608 -1.201685  1.261670
# 7  1.531601 -0.090997 -0.620204 -1.214064  0.592071
# 8 -0.159512 -0.595757  0.074488  0.362174 -0.015148
# 9 -0.476920  0.583005  1.687982 -1.439186 -2.018056

# %%
import networkx as nx
import matplotlib.pyplot as plt

G = nx.Graph()
G.add_node(1)
G.add_node(2)
G.add_node(3)
G.add_edge(2, 3)
G.add_edge(1, 3)
G.add_edge(1, 2)
subax1 = plt.subplot(121)
nx.draw(G, with_labels=True, font_weight='bold')
